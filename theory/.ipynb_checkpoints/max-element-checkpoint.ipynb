# %%
# %matplotlib widget
# %matplotlib ipympl

import pandas as pd
import datetime
import matplotlib.pyplot as plt
import random
from statistics import mean

import util.benchmark as benchmark
import util.plotting as plotting

# %% [markdown]
# # Algoritmo de maximo lineal
# Tenemos la siguiente implementacion para decidir dada una lista y un elemento, si este elemento pertenece a la lista.

# %%
def maxElement(amount, elems):
    maxElem = elems[0]
    for e in elems:
        maxElem = max(maxElem, e)
        
    return maxElem

# %%
print(maxElement(3,[1,2,3]))
print(maxElement(3,[1,2,3]))
# Out:
# 3
# 3

# %%
N = 100000
ITS = 100
Ns = list(range(1,N+1, int(N/ITS)))

# %% [markdown]
# ## Peor caso: No existe
# Este es cuando no existe el elemento que buscamos, y tenemos que buscar por toda la lista.

# %%
worstCases = [([e for e in range(i)], i) for i in Ns]
worstResults = benchmark.benchmarkFuncForCases(10, maxElement, worstCases)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 worstCases = [([e for e in range(i)], i) for i in Ns]
# ----> 2 worstResults = benchmark.benchmarkFuncForCases(10, maxElement, worstCases)
#
# File /algorithms-workshop/util/benchmark.py:20, in benchmarkFuncForCases(times, f, cases)
#      18 results = []
#      19 for case in cases:
# ---> 20     results.append(benchmarkFunc(times, f, *case))
#      22 return results
#
# File /algorithms-workshop/util/benchmark.py:13, in benchmarkFunc(times, f, *args)
#      10 def benchmarkFunc(times,f, *args):
#      11     func = lambda: f(*args)
# ---> 13     times = [measureTime(func) for _ in range(times)]
#      15     return statistics.fmean(times)
#
# File /algorithms-workshop/util/benchmark.py:13, in <listcomp>(.0)
#      10 def benchmarkFunc(times,f, *args):
#      11     func = lambda: f(*args)
# ---> 13     times = [measureTime(func) for _ in range(times)]
#      15     return statistics.fmean(times)
#
# File /algorithms-workshop/util/benchmark.py:6, in measureTime(func)
#       4 def measureTime(func):
#       5     start = time.process_time()
# ----> 6     func()
#       7     end = time.process_time()
#       8     return (end - start)
#
# File /algorithms-workshop/util/benchmark.py:11, in benchmarkFunc.<locals>.<lambda>()
#      10 def benchmarkFunc(times,f, *args):
# ---> 11     func = lambda: f(*args)
#      13     times = [measureTime(func) for _ in range(times)]
#      15     return statistics.fmean(times)
#
# Cell In[7], line 2, in maxElement(amount, elems)
#       1 def maxElement(amount, elems):
# ----> 2     maxElem = elems[0]
#       3     for e in elems:
#       4         maxElem = max(maxElem, e)
#
# TypeError: 'int' object is not subscriptable

# %%
on = lambda list,_: len(list)

plotting.getFuncComplexityAnalysis(Ns, worstCases, worstResults, "N", on, "N", on, "N", on, 1)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Mejor caso: Primer elemento
# El elemento que se busca es el primera de la lista.

# %%
bestCases = [([e for e in range(i)], 0) for i in Ns]
bestResults = benchmark.benchmarkFuncForCases(10, findElement, bestCases)

# %%
o1 = lambda list,_: 1

plotting.getFuncComplexityAnalysis(Ns, bestCases, bestResults, "1", o1, "1", o1, "1", o1, 1)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Caso promedio: Distribuido uniforme en lista
# Si asumimos que el elemento que nos piden pertenece, y la distribucion de los numeros de la lista responde a una uniforme, entonces va a tender a recorre la mitad de la lista en promedio.

# %%
avgCases = [([e for e in range(i)], 0) for i in Ns]
avgResultsRuns = []
for _ in range(20):
    avgCasesRun = [([e for e in range(i)], random.randint(0,i)) for i in Ns]
    avgResultsRun = benchmark.benchmarkFuncForCases(10, findElement, avgCasesRun)
    
    avgResultsRuns.append(avgResultsRun)
avgResults = list(map(mean, zip(*avgResultsRuns)))

# %%
on = lambda list,_: len(list)

plotting.getFuncComplexityAnalysis(Ns, avgCases, avgResults, "N", on, "N", on, "N", on, 1)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
