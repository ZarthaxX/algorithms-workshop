# %%
# %matplotlib widget
# %matplotlib ipympl

import pandas as pd
import datetime
import matplotlib.pyplot as plt
import random
from statistics import mean

import util.benchmark as benchmark
import util.plotting as plotting

# %% [markdown]
# # Dictionary

# %% [markdown]
# ## Insercion

# %%
def insert(e, d):
    d[e] = e

# %%
N = 100000
ITS = 100
Ns = list(range(1,N+1, int(N/ITS)))
insertCases = [(i-1, dict([(e,e) for e in range(i)])) for i in Ns]
insertResults = benchmark.benchmarkFuncForCases(1, insert, insertCases, copyCase = True)

# %%
o1 = lambda e, d: 1

plotting.plotFuncBigOAnalysis(Ns, insertCases, insertResults, "1", o1, 1)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Busqueda

# %%
def search(e, d):
    return e in d

# %%
N = 1000000
ITS = 100
Ns = list(range(1,N+1, int(N/ITS)))
searchCases = [(i-1, dict([(e,e) for e in range(i)])) for i in Ns]
searchResults = benchmark.benchmarkFuncForCases(1000, search, searchCases)

# %%
o1 = lambda e, d: 1

plotting.plotFuncBigOAnalysis(Ns, searchCases, searchResults, "1", o1, 1)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Eliminacion

# %%
def remove(e, d):
    del d[e]

# %%
N = 100000
ITS = 100
Ns = list(range(1,N+1, int(N/ITS)))
removeCases = [(i-1, dict([(e,e) for e in range(i)])) for i in Ns]
removeResults = benchmark.benchmarkFuncForCases(1, remove, removeCases, copyCase = True)

# %%
o1 = lambda e, d: 1

plotting.plotFuncBigOAnalysis(Ns, removeCases, removeResults, "1", o1, 1)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Set

# %% [markdown]
# ## Insercion

# %%
def insert(e, d):
    d.add(e)

# %%
N = 100000
ITS = 100
Ns = list(range(1,N+1, int(N/ITS)))
insertCases = [(i-1, set([e for e in range(i)])) for i in Ns]
insertResults = benchmark.benchmarkFuncForCases(1, insert, insertCases, copyCase = True)

# %%
o1 = lambda e, d: 1

plotting.plotFuncBigOAnalysis(Ns, insertCases, insertResults, "1", o1, 1)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Busqueda

# %%
def search(e, d):
    return e in d

# %%
N = 1000000
ITS = 100
Ns = list(range(1,N+1, int(N/ITS)))
insertCases = [(i-1, set([e for e in range(i)])) for i in Ns]
searchResults = benchmark.benchmarkFuncForCases(1000, search, searchCases)

# %%
o1 = lambda e, d: 1

plotting.plotFuncBigOAnalysis(Ns, searchCases, searchResults, "1", o1, 1)

# %% [markdown]
# ## Eliminacion

# %%
def remove(e, s):
    s.remove(e)

# %%
N = 100000
ITS = 100
Ns = list(range(1,N+1, int(N/ITS)))
removeCases = [(i-1, set([e for e in range(i)])) for i in Ns]
removeResults = benchmark.benchmarkFuncForCases(1, remove, removeCases, copyCase = True)

# %%
o1 = lambda e, d: 1

plotting.plotFuncBigOAnalysis(Ns, removeCases, removeResults, "1", o1, 1)
